# %%
import sys
import plotgf as pg
from pylsa.rbc1d import solve_rbc1d

# Parameters
Ny    = 51
alpha = 3.1
Ra = 1708
Pr = 1.0

evals,evecs = solve_rbc1d(Ny=Ny,Ra=Ra,Pr=Pr,alpha=alpha,plot=True)
# Out:
#    3 largest eigenvalues:
#    3: -0.000e+00 -1.359e+00j
#    2: -0.000e+00 -1.030e+00j
#    1:  0.000e+00  3.286e-05j

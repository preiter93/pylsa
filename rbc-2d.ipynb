# %%
import sys
import numpy as np
from pylsa.rbc2d import solve_rbc2d
import matplotlib.pyplot as plt

# Parameters
Gamma = 4.0
Ny    = 15
Nx    = int(Ny*Gamma)
Ra = 1800
Pr = 1.0

evals,evecs,x,z = solve_rbc2d(Nx=Nx,Ny=Ny,Ra=Ra,Pr=Pr,aspect=Gamma,
                              directsolver=False,plot=True)
# Out:
#    3 largest eigenvalues:
#    3: -1.336e-18 -5.667e-02j
#    2: -4.334e-21 -1.187e-02j
#    1:  3.039e-23 -1.567e-03j
# Time used:    74.40 s.
